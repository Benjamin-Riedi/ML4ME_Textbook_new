# %% [markdown]
# # Improve Me
#
# When I was a student, I wrote this beautiful piece of code. It does not work. Help me improve it.
#
# Tip: use the instructions from [the ML4ME appendix](https://ideal.umd.edu/ML4ME_Textbook/appendices/helpful_tooling.html).
#
# ## Imports
#
# You can add your own extra imports if you need.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
import trackio as wandb

# %% [markdown]
# ## Data Generation and Processing

# %% [markdown]
# ### Context
# Imagine a factory producing metal plates for some engineering application.
#
# Each plate is supposed to have uniform properties, but in reality, manufacturing imperfections (slightly thinner material, internal stresses, micro-defects) can cause some parts of a plate to bend more than others when pressure is applied.
#
# Quality control wants to measure deflection at every point `(x, y)` of the plate. This requires physical experiments and is slow and expensive. That's why we're building an ML model that is able to predict deflection `z` at any `(x, y)` point.
#
# We don't have exact measures so we will construct an artificial dataset where the deflection is actually not uniform on one side (the plate has a thinner corner).

# %%
# Our physical model

def generate_plate_data(n_samples: int = 100, n_plates: int = 5, noise_level: float = 0.2):
    """Generates multiple plates with a defect.

    Args:
        n_samples: number of points per plate
        n_plates: number of plates
        noise_level: noise level in the deflection

    Returns:
        X: input points
        y: deflection
    """
    n_sample_per_side = int(n_samples**0.5)
    x = torch.linspace(-2, 2, n_sample_per_side)
    y = torch.linspace(-2, 2, n_sample_per_side)
    xx, yy = torch.meshgrid(x, y, indexing="ij")
    X_base = torch.stack([xx.flatten(), yy.flatten()], dim=1)

    # Base deflection
    r2 = X_base[:,0]**2 + X_base[:,1]**2
    Z_base = torch.tanh(r2 / 5.0) * 5.0

    # Mask for the top-right corner defect
    corner_mask = (X_base[:,0] > 1.0) & (X_base[:,1] > 0.5)
    # Aggressive corner defect with y-dependent variation
    Z_base[corner_mask] *= 1 + 2*((X_base[corner_mask,0]-1.0)**2 + (X_base[corner_mask,1]-0.5)**2)
    

    # Replicate experiments with noise for different plates
    X_list, y_list = [], []  # noqa: N806
    for _ in range(n_plates):
        Z_noisy = Z_base + noise_level * torch.randn_like(Z_base)  # noqa: N806
        X_list.append(X_base)
        y_list.append(Z_noisy)

    # assemble the data
    X = torch.cat(X_list, dim=0)  # noqa: N806
    y = torch.cat(y_list, dim=0)
    idx = torch.argsort(X[:,0])
    X = X[idx]  # noqa: N806
    y = y[idx]

    return X, y

# %%
#Set random seed for reproducibility
rng = np.random.default_rng(42)  # seed NumPy random
torch.manual_seed(42)  # seed PyTorch
torch.cuda.manual_seed(42)  # see PyTorch CUDA (for NVIDIA GPUs)
torch.backends.cudnn.deterministic = True  # tell PyTorch to use deterministic kernels
torch.backends.cudnn.benchmark = (
    False  # removes internal optimizations that can cause non-determinism
)

# %%
# Generate full dataset
X_all, y_all = generate_plate_data(n_samples=100, n_plates=5, noise_level=0.4)
total_samples = X_all.shape[0]

# Visualize the data
def visualize_data(X: torch.Tensor,  # shape (N, 2) with x,
    y: torch.Tensor,  # shape (N,) with deflection
    open_window: bool = False,
    log: bool = False,
):
    fig = plt.figure(figsize=(9,7))
    ax = fig.add_subplot(111, projection="3d")
    ax.scatter(X[:,0], X[:,1], y, c="blue", alpha=0.3)
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("deflection z")
    ax.set_title("Plate deflection")
    plt.show()

# visualize test/train split

def visualize_split(X_train: torch.Tensor,  # shape (N, 2) with x,
    y_train: torch.Tensor,  # shape (N,) with deflection
    X_test: torch.Tensor,  # shape (N, 2) with x,
    y_test: torch.Tensor,  # shape (N,) with deflection
    open_window: bool = False,
    log: bool = False,
):
    fig = plt.figure(figsize=(9,7))
    ax = fig.add_subplot(111, projection="3d")
    ax.scatter(X_train[:,0], X_train[:,1], y_train, c="blue", alpha=0.3, label="train")
    ax.scatter(X_test[:,0], X_test[:,1], y_test, c="red", alpha=0.3, label="test")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("deflection z")
    ax.set_title("Plate deflection - train/test split")
    ax.legend()
    plt.show()
    

visualize_data(X_all, y_all)

# Split into train/test naively
train_ratio = 0.7
train_size = int(total_samples * train_ratio)
X_train, y_train = X_all[:train_size], y_all[:train_size]
X_test, y_test   = X_all[train_size:], y_all[train_size:]

visualize_split(X_train, y_train, X_test, y_test)

# Split properly using sklearn

X_train, X_test, y_train, y_test = train_test_split(X_all.numpy(), y_all.numpy(), train_size=0.7, random_state=42)
X_train, X_test = torch.tensor(X_train, dtype=torch.float32), torch.tensor(X_test, dtype=torch.float32)
y_train, y_test = torch.tensor(y_train, dtype=torch.float32), torch.tensor(y_test, dtype=torch.float32)


visualize_split(X_train, y_train, X_test, y_test)

# %%
# Data preprocessing
x_scaler = StandardScaler()
y_scaler = StandardScaler()

# Normalizing our data, don't forget to unnormalize the predictions later!
X_train_scaled = torch.from_numpy(x_scaler.fit_transform(X_train.numpy())).float()
X_test_scaled = torch.from_numpy(x_scaler.transform(X_test.numpy())).float()
y_train_scaled = torch.from_numpy(y_scaler.fit_transform(y_train.numpy().reshape(-1, 1))).float().squeeze()
y_test_scaled = torch.from_numpy(y_scaler.transform(y_test.numpy().reshape(-1, 1))).float().squeeze()

# %% [markdown]
# ## Model definition

# %%
hyperparams = {
    "learning_rate": 1e-3,
    "hidden_layers": 8,
    "hidden_units": 20,
    "activation": "ReLU",
}

wandb.init(project="plate_bending", config=hyperparams)

# Model definition
class NetleF(nn.Module):
    """A very efficient neural network for the given task, probably the best for the job."""
    def __init__(self):
        super().__init__()
        layers = []
        layers.append(nn.Linear(2, 20)) # input layer
        for _ in range(8):
            layers.append(nn.ReLU()) # activation function
            layers.append(nn.Linear(20, 20)) # hidden layer
        layers.append(nn.ReLU()) # activation function
        layers.append(nn.Linear(20, 1)) # output layer
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ## Training

# %%
model = NetleF()

# Optimizer and loss
optimizer = optim.Adam(model.parameters(), lr=0.01)
loss_fn = nn.MSELoss()


# Training loop
for epoch in range(200):
    y_pred_scaled = model(X_train_scaled).squeeze()
    loss = loss_fn(y_pred_scaled, y_train_scaled)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 5 == 0:
        with torch.no_grad(): # no gradients coming from the test set
            test_pred_scaled = model(X_test_scaled).squeeze()
            test_loss = loss_fn(test_pred_scaled, y_test_scaled)
        print(f"Epoch {epoch:3d} | Train loss: {loss.item():.4f} | Test loss: {test_loss.item():.4f}")
# Out:
# Epoch   0 | Train loss: 1.0017 | Test loss: 1.4145
# Epoch   5 | Train loss: 0.9953 | Test loss: 1.4059
# Epoch  10 | Train loss: 0.9313 | Test loss: 1.3054
# Epoch  15 | Train loss: 0.7004 | Test loss: 0.9364
# Epoch  20 | Train loss: 0.2101 | Test loss: 0.1406
# Epoch  25 | Train loss: 0.4634 | Test loss: 0.2067
# Epoch  30 | Train loss: 0.2724 | Test loss: 0.1032
# Epoch  35 | Train loss: 0.1223 | Test loss: 0.1331
# Epoch  40 | Train loss: 0.1175 | Test loss: 0.1085
# Epoch  45 | Train loss: 0.0773 | Test loss: 0.0812
# Epoch  50 | Train loss: 0.0688 | Test loss: 0.0755
# Epoch  55 | Train loss: 0.0591 | Test loss: 0.0546
# Epoch  60 | Train loss: 0.0413 | Test loss: 0.0347
# Epoch  65 | Train loss: 0.0324 | Test loss: 0.0296
# Epoch  70 | Train loss: 0.0258 | Test loss: 0.0236
# Epoch  75 | Train loss: 0.0207 | Test loss: 0.0195
# Epoch  80 | Train loss: 0.0174 | Test loss: 0.0179
# Epoch  85 | Train loss: 0.0152 | Test loss: 0.0147
# Epoch  90 | Train loss: 0.0134 | Test loss: 0.0131
# Epoch  95 | Train loss: 0.0134 | Test loss: 0.0140
# Epoch 100 | Train loss: 0.0149 | Test loss: 0.0141
# Epoch 105 | Train loss: 0.0133 | Test loss: 0.0136
# Epoch 110 | Train loss: 0.0125 | Test loss: 0.0140
# Epoch 115 | Train loss: 0.0117 | Test loss: 0.0141
# Epoch 120 | Train loss: 0.0104 | Test loss: 0.0123
# Epoch 125 | Train loss: 0.0095 | Test loss: 0.0121
# Epoch 130 | Train loss: 0.0092 | Test loss: 0.0109
# Epoch 135 | Train loss: 0.0086 | Test loss: 0.0105
# Epoch 140 | Train loss: 0.0083 | Test loss: 0.0100
# Epoch 145 | Train loss: 0.0079 | Test loss: 0.0095
# Epoch 150 | Train loss: 0.0081 | Test loss: 0.0094
# Epoch 155 | Train loss: 0.0081 | Test loss: 0.0098
# Epoch 160 | Train loss: 0.0078 | Test loss: 0.0090
# Epoch 165 | Train loss: 0.0077 | Test loss: 0.0094
# Epoch 170 | Train loss: 0.0088 | Test loss: 0.0110
# Epoch 175 | Train loss: 0.0439 | Test loss: 0.0202
# Epoch 180 | Train loss: 0.0105 | Test loss: 0.0246
# Epoch 185 | Train loss: 0.0102 | Test loss: 0.0161
# Epoch 190 | Train loss: 0.0118 | Test loss: 0.0100
# Epoch 195 | Train loss: 0.0123 | Test loss: 0.0090

# %% [markdown]
# ## Visualization of Results

# %%
# Plot predictions vs targets in 3d
with torch.no_grad():
    test_pred_scaled = model(X_test_scaled).squeeze()
    test_pred = torch.from_numpy(y_scaler.inverse_transform(test_pred_scaled.numpy().reshape(-1, 1))).float().squeeze()
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection="3d")
    ax.scatter(X_test[:, 0], X_test[:, 1], test_pred, c="blue", alpha=0.4, label="Predictions")
    ax.scatter(X_test[:, 0], X_test[:, 1], y_test, c="red", marker="x", alpha=0.6, label="Targets")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    ax.set_title("Predictions vs Targets")
    ax.legend()
    plt.show()
